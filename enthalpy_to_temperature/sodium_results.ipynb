# %% [markdown]
# # Evaluation of methods for converting enthalpy to temperature: SODIUM
# In this notebook the results of the evaluation are reported for **sodium**.
#
# Refer to the _enthalpy2temperature.ipynb_ notebook for the complete description of the procedure adopted. The same procedure has been adopted with the following differences:
# -  the datasets used for interpolation and as reference in the accuracy evaluation are not constructed using _lbh15_, but with the enthalpy correlation from (J. K. Fink and L. Leibowitz, "Thermodynamic and Transport Properties of Sodium Liquid and Vapor," ANL-RE-95-2, Argonne National Laboratory, 1995);
# - the datasets used for interpolation have different depths: in the _sodium_ case database sizes range from 2500 to 10000 datapoints.

# %% [markdown]
# ## Application and comparison

# %%
from temp_from_h import newton_method, table_method, poly_method
from time_and_accuracy import eval_time, eval_accuracy, table_method_summary, \
    get_poly_results
from plots import plot_table_evaluation, plot_polynomium_results, \
    plot_accuracy_comparison
from _commons import DB_SIZES, T_IN
import numpy as np 
from dassh import Material
from tabulate import tabulate
import os


MATERIAL: str = 'sodium'
"""Material to be used"""
DB_PATH_PREFIX: str = f"{MATERIAL}_"
"""Prefix for the path to the data files"""
DB_PATH_SUFFIX: str = ".csv"
"""Suffix for the path to the data files"""
DATA_FOLDER: str = os.path.join('data', MATERIAL)
"""Folder containing the data files"""
reference = np.genfromtxt(os.path.join(DATA_FOLDER, f'{MATERIAL}_ref.csv'), 
                          delimiter=',')
coolant = Material(MATERIAL, T_IN)

# %% [markdown]
# ## TAB method analysis

# %%
results_table = {}
for s in DB_SIZES[MATERIAL]:
    path = DB_PATH_PREFIX + str(s) + DB_PATH_SUFFIX
    data_path = os.path.join(DATA_FOLDER, path)
    results_table[s] = table_method_summary(reference, data_path)

# %% [markdown]
# Below the resulting accuracy and computational effort for `table_method`:

# %%
plot_table_evaluation(results_table, MATERIAL)

# %% [markdown]
# The largest dataset (10000 data) provides the best accuracy with limited time effort. This dataset will be hereafter used as the base for interpolation in the _Table interpolation_ method.

# %% [markdown]
# ## Fitting polynomial

# %%
data_path = DB_PATH_PREFIX + str(DB_SIZES[MATERIAL][-1]) + DB_PATH_SUFFIX
data_path = os.path.join(DATA_FOLDER, data_path)
print(f"Using data file: {data_path}")
data = np.genfromtxt(data_path, delimiter=',')
poly_results = get_poly_results(reference, data)

plot_polynomium_results(poly_results, MATERIAL)
# Out:
# Using data file: data/sodium/sodium_10000.csv
# Evaluating polynomium degree 1...
# Evaluating polynomium degree 2...
# Evaluating polynomium degree 3...
# Evaluating polynomium degree 4...
# Evaluating polynomium degree 5...
# Evaluating polynomium degree 6...
# Evaluating polynomium degree 7...
# Evaluating polynomium degree 8...
# Evaluating polynomium degree 9...
# Evaluating polynomium degree 10...
# Evaluating polynomium degree 11...
# Evaluating polynomium degree 12...
# Evaluating polynomium degree 13...
# Evaluating polynomium degree 14...
# /home/fpepe/programs/dassh_nc/enthalpy_to_temperature/time_and_accuracy.py:260: RankWarning: Polyfit may be poorly conditioned
#   coeffs_T2h = np.polyfit(data[:,0], data[:,1], deg=dd)
# /home/fpepe/programs/dassh_nc/enthalpy_to_temperature/time_and_accuracy.py:260: RankWarning: Polyfit may be poorly conditioned
#   coeffs_T2h = np.polyfit(data[:,0], data[:,1], deg=dd)
# ...

# %% [markdown]
# _NumPy_ issues a _RankWarning_ for polynomials of degree >= 14. As a consequence, the 13-th degree polynomial will be hereafter considered as the most accurate and reliable.

# %% [markdown]
# ## Time effort

# %%
table = [["Newton", eval_time(newton_method, coolant=coolant)],
         ["Table", results_table[DB_SIZES[MATERIAL][-1]]['time']],
         ["Polynomium (13 deg)", poly_results['time_poly'][12]]]

print(tabulate(table, headers=["Method", "Computational effort [s]"], 
               tablefmt="github"))
# Out:
# | Method              |   Computational effort [s] |
# |---------------------|----------------------------|
# | Newton              |                0.000588341 |
# | Table               |                5.43198e-05 |
# | Polynomium (13 deg) |                3.14165e-05 |

# %% [markdown]
# ## Accuracy evaluation

# %%
err_newton = eval_accuracy(newton_method, reference, coolant=coolant)
err_table = eval_accuracy(table_method, reference, data_path=data_path)
err_poly = eval_accuracy(poly_method, reference, 
                           coeffs_T2h=np.polyfit(data[:,0], data[:,1], deg=13), 
                           coeffs_h2T=np.polyfit(data[:,1], data[:,0], deg=13))
plot_accuracy_comparison(reference, err_newton, err_table, err_poly, MATERIAL)
# Out:
# Temperature 372.0 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.1627327750422 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.1627162716272 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.32543254325435 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.48814881488147 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.65086508650865 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.8135813581358 K is below the validity range of density for sodium: 400.0 K
# Temperature 372.976297629763 K is below the validity range of density for sodium: 400.0 K
# Temperature 373.1390139013901 K is below the validity range of density for sodium: 400.0 K
# Temperature 373.3017301730173 K is below the validity range of density for sodium: 400.0 K
# ...

# %% [markdown]
# # Conclusions
# The following methods for converting enthalpy to temperature were compared: _NEW_, _TAB_ (based on the _NumPy_ function `interp`), and _POLY_ (based on the _NumPy_ functions `polyfit` and `polyval`). Both time effort and accuracy were evaluated.
#
# Accuracy was assessed against a reference dataset of 10000 points calculated using a reference correlation (J. K. Fink and L. Leibowitz, "Thermodynamic and Transport Properties of Sodium Liquid and Vapor," ANL-RE-95-2, Argonne National Laboratory, 1995).
#
# _NEW_method is the most computationally expensive.  _TAB_ provides the greatest accuracy.
#
# Although _TAB_ is more accurate than _POLY_ (with maximum errors of the order of $10^{-11}$ and $10^{-8}$, respectively), the latter is slightly faster. Considering the _POLY_ method accurate enough, it is chosen to be implemented.
